# %% [markdown]
# # Pandas Practice
# ## This is a Practice Workspace for Pandas in Jupyter Notebook
# ## All practice files were from Youtube\CodeCamp
# ## Some practices might be modified by users

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_raw=pd.read_csv('population_total.csv')
df_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
df_pivot=df_raw.pivot_table(index='year', columns='country', values='population')
df_pivot
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
df_pivot_selected=df_pivot[['Afghanistan','Argentina','Vietnam','China','Brazil','Canada','Denmark','France','Japan','Russia','Turkey','United Kingdom','United States']]

# %%
df_pivot_selected
# Out:
# country  Afghanistan   Argentina     Vietnam         China       Brazil  \
# year
# 1955.0     8270991.0  18789418.0  28147443.0  6.122416e+08   62533919.0
# 1960.0     8996973.0  20481779.0  32670039.0  6.604081e+08   72179226.0
# 1965.0     9956320.0  22159650.0  37858951.0  7.242190e+08   83373530.0
# 1970.0    11173642.0  23880561.0  43404793.0  8.276014e+08   95113265.0
# 1975.0    12689160.0  25865776.0  48718189.0  9.262409e+08  107216205.0
# 1980.0    13356511.0  27896528.0  54281846.0  1.000089e+09  120694009.0
# 1985.0    11938208.0  30216279.0  60896721.0  1.075589e+09  135274080.0
# 1990.0    12412308.0  32618651.0  67988862.0  1.176884e+09  149003223.0
# 1995.0    18110657.0  34828170.0  74910461.0  1.240921e+09  162019896.0
# 2000.0    20779953.0  36870787.0  79910412.0  1.290551e+09  174790340.0
# 2005.0    25654277.0  38892931.0  83832661.0  1.330776e+09  186127103.0
# 2010.0    29185507.0  40895752.0  87967651.0  1.368811e+09  195713635.0
# ...

# %%
df_pivot_selected.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# df_pivot_selected.pop('China')
# df_pivot_selected.plot()

# %%
df_pct_change=df_pivot_selected.pct_change()*100
df_pct_change.plot(kind='line',xlabel='Year',ylabel='Population Growth Rate', title='Popualtion Growth Rate% by Country',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Popualtion Growth Rate% by Country'}, xlabel='Year', ylabel='Population Growth Rate'>

# %%
df_pct_change
# Out:
# country  Afghanistan  Argentina    Vietnam      China     Brazil     Canada  \
# year
# 1955.0           NaN        NaN        NaN        NaN        NaN        NaN
# 1960.0      8.777449   9.006990  16.067520   7.867238  15.424120  13.868029
# 1965.0     10.662997   8.192018  15.882785   9.662346  15.509039   9.976660
# 1970.0     12.226626   7.765967  14.648694  14.275023  14.080890   8.897227
# 1975.0     13.563331   8.313100  12.241496  11.918720  12.724766   7.883004
# 1980.0      5.259221   7.851116  11.420082   7.972910  12.570678   5.887529
# 1985.0    -10.618814   8.315555  12.186164   7.549339  12.080194   5.438548
# 1990.0      3.971283   7.950588  11.646179   9.417564  10.149131   6.978140
# 1995.0     45.908859   6.773790  10.180490   5.441223   8.735833   5.892358
# 2000.0     14.738814   5.864842   6.674570   3.999469   7.882022   4.883499
# 2005.0     23.456858   5.484407   4.908308   3.116934   6.485921   5.152041
# ...
